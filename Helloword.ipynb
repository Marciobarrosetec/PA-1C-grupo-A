# %% [markdown]
# <a href="https://colab.research.google.com/github/Marciobarrosetec/PA-1C-grupo-A/blob/main/Helloword.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print ("Hello World!!")
# Out:
# Hello World!!
